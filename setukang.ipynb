# %% [markdown]
# # **Welcome To Tumbal Proyek**
# script created by **OGdangID**
#
# Telegram : [@OGdangID](https://t.me/OGdangID)

# %%
#@title **Tukang pacul**

import os

username = "user" 
password = "y" 

print("Creating User and Setting it up")

# Creation of user
os.system(f"useradd -m {username}")

# Add user to sudo group
os.system(f"adduser {username} sudo")
    
# Set password of user to 'root'
os.system(f"echo '{username}:{password}' | sudo chpasswd")

# Change default shell from sh to bash
os.system("sed -i 's/\/bin\/sh/\/bin\/bash/g' /etc/passwd")

print("User Created and Configured")
# !cd /home/user && git clone https://github.com/onyip/tukang.git
# !sudo apt install screen -y
# !pkill screen
# !cd /home/user/tukang && screen -d -m ./setukang.sh

# %%
#@title **Ngaso Disit**
# !sleep 10
print('ngaso rampung!')

# %%
#@title **Niliki Pacul**
import time
import psutil
for x in range(5):
  Tn = psutil.cpu_percent()
  print(f'Tenaga : {Tn} %')
  time.sleep(4)
